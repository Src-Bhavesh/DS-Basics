# %% [markdown]
# <a href="https://colab.research.google.com/github/Src-Bhavesh/DS-Basics/blob/main/03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Function**

# %%
def func_name(parameter):
  # body

# %%
def sum(a,b):
  return a+b

print(sum(2,3))
# Out:
# 5

# %% [markdown]
# ### Lambda **Function**

# %%
sum=lambda a , b : a+b
print(sum(2,3))
# Out:
# 5

# %% [markdown]
# # **String**

# %%
str =""
print(len(str))

st =input()
print(len(st))
# Out:
# 0

# %%
str = "   my name is bhavesh"
a=str.upper()
print(a)

a=str.lower()
print(a)

a=str.title()
print(a)

a=str.capitalize()
print(a)


a=str.strip()
print(a)
# Out:
#    MY NAME IS BHAVESH
#    my name is bhavesh
#    My Name Is Bhavesh
#    my name is bhavesh
# ['', '', '', 'my', 'name', 'is', 'bhavesh']
# my name is bhavesh

# %%
a = "  today "
b = "    weather   "
c = "is GooD"

a = a.strip(' ')
a=a.capitalize()
b= b.strip()
c=c.lower()
str = a +" "+b+" "+c
print(str)

str = str.replace("good","bad")
print(str)

print(str.startswith("Today"))
print(str.endswith("bad") )
# Out:
# Today weather is good
# Today weather is bad
# True
# True

# %%
s="hello world"
print(s[:5])
print(s[6:])
# Out:
# hello
# world

# %% [markdown]
# # **Set**

# %%
st ={2,2,3,3,4,56,7,4}
print(st)
# Out:
# {2, 3, 4, 7, 56}

# %% [markdown]
# # **Dictornary**

# %%
dct ={
    "name":"XYZ",
    "Roll no":28,
    "class":"Alpha",
    "Age":18

}

print(dct)
print(dct["name"])
dct["id"]=12
print(dct)
# Out:
# {'name': 'XYZ', 'Roll no': 28, 'class': 'Alpha', 'Age': 18}
# XYZ
# {'name': 'XYZ', 'Roll no': 28, 'class': 'Alpha', 'Age': 18, 'id': 12}
